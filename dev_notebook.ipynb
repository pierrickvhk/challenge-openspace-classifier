# %% [markdown]
# # Open Space Organizer
#
# We want to create a program that assigns 24 people to 6 tables in an openspace. Before getting started, take inventory what do we need:
#
# - People
# - Seats & Tables
# - An OpenSpace
#
# It's a good practice to start simple while you grasp the logic of the program you are trying to build and test often. For us this can translate to,
#
# - People -> List of Names (later we can figure out how to use a file)
# - Seats & Tables -> Class
# - An OpenSpace -> Class
#
# Below I've created a list of your new colleagues for reference!

# %%
new_collegues = ["Aleksei","Amine","Anna","Astha","Brigitta",
                 "Bryan","Ena","Esra","Faranges","Frédéric",
                 "Hamideh","Héloïse","Imran","Intan K.",
                 "Jens","Kristin","Michiel","Nancy","Pierrick",
                 "Sandrine","Tim","Viktor","Welederufeal","Živile"]

# %% [markdown]
# ## Step 1: Build a Seat
#
# Create a class called `Seat` with two attributes:
#
# - `free` which is a boolean.
# - `occupant` which is a string.
#
# and 2 functions :
#
# - `set_occupant(name)` which allows the program to assign someone a seat if it's free
# - `remove_occupant()` which  remove someone from a seat and return the name of the person occupying the seat before

# %%
# Your code here

class Seat:
    """Class to define a seat"""
    def __init__(self) -> None:
        self.free : bool = True
        self.occupant : str = ""
    
    def set_occupant(self, name : str) -> bool:
        """ This function will assign someone to a seat if its free"""
        if self.free and name.strip():
            self.occupant = name
            self.free = False
            return True
        else: 
            return False
    
    def remove_occupant(self) -> str:
        """ this function will remove the previous person and return the name of the removed person"""
        previous_person = self.occupant
        self.occupant = "" 
        self.free = True
        return previous_person

# %%
# Test your code (assign yourself you a Seat)
class Seat:
    """Class to define a seat"""
    def __init__(self):
        self.free = True
        self.occupant = ""
    
    def set_occupant(self, name):
        """ This function will assign someone to a seat if its free"""
        if self.free and isinstance(name, str) and name.strip():
            self.occupant = name
            self.free = False
            return True
        else: 
            return False
    
    def remove_occupant(self):
        """ this function will remove the previous person and return the name of the removed person"""
        previous_person = self.occupant
        self.occupant = "" 
        self.free = True
        return previous_person

# Test
p = Seat()
print(p.free) #1ste check to show a free seat
p.set_occupant("Pierrick")
print(p.occupant, p.free) #2th check to add a person to a seat
print(p.remove_occupant())
print(p.free) #3th check to remove a person from a seat
# Out:
# True
# Pierrick False
# Pierrick
# True

# %% [markdown]
# What is the input and the output of your Seat class? Does it make sense?
#
# ## Step 2: Build a Table
#
# Create a class `Table` with ? attributes:
#
# - `capacity` which is an integer
# - `seats` which is a list of `Seat` objects (size = `capacity`)
#
# and 3 functions :
# - `has_free_spot()` that returns a boolean (True if a spot is available)
# - `assign_seat(name)` that places someone at the table
# - `left_capacity()` that returns an integer
#
# Question: Which attributes make sense to give? For now let's say we want to build 6 tables with 4 seats.

# %%
# Your code here
"""TYPIUNG TO ADD"""
class Table:
    """Class to define a table."""
    def __init__(self, capacity : int = 4, name : str  = "Table"):
        if capacity <= 0: 
            raise Exception("capacity needs to be > 0.") #gives an exception if there is no capacity
        
        self.capacity = capacity 
        self.seats = [Seat() for _ in range(capacity)] #list of Seat objects with the max capacity 
        self.name = name

    def has_free_spot(self) -> bool:
        """ This function will check if the table still has free spots"""
        for seat in self.seats:
            if seat.free:
                return True
        return False
    
    def assign_seat(self, name) -> bool:
        """ 
        This function will check if there is a spot left and then add the person to the table & return True (it worked),
        if the table is full it will return false.
        """
        for seat in self.seats:
            if self.has_free_spot():
                seat.set_occupant(name)
                return True
        return False

        
    def left_capacity(self) -> int:
        """ This function will give the number of free seats at the table"""
        free_spots = 0
        for seat in self.seats: 
            if seat.free:
                free_spots += 1
        return free_spots
    
    def show_table(self):
        print(f"{self.name} has a capacity of: {self.capacity}")
        for seat in self.seats:
            if seat.free:
                print("empthy seat")
            else:
                print(seat)

# %%
# Test your code (assign the colleagues at your table to a Table)

class Table:
    """Class to define a table."""
    def __init__(self, capacity = 4, name = "Table"):
        if capacity <= 0: 
            raise Exception("capacity needs to be > 0.") #gives an exception if there is no capacity
        
        self.capacity = capacity 
        self.seats = [Seat() for _ in range(capacity)] #list of Seat objects with the max capacity 
        self.name = name

    def has_free_spot(self):
        """ This function will check if the table still has free spots"""
        for seat in self.seats:
            if seat.free:
                return True
        return False
    
    def assign_seat(self, name):
        """ 
        This function will check if there is a spot left and then add the person to the table & return True (if it worked),
        if the table is full it will return false.
        """
        for seat in self.seats:
            if self.has_free_spot():
                seat.set_occupant(name)
                return True
        return False

        
    def left_capacity(self):
        """ This function will give the number of free seats at the table"""
        free_spots = 0
        for seat in self.seats: 
            if seat.free:
                free_spots += 1
        return free_spots
    
    def show_table(self):
        print(f"{self.name} has a capacity of: {self.capacity}")
        for seat in self.seats:
            enumerate(s)
            if seat.free:
                print("empthy seat")
            else:
                print(seat.occupant)
                enumerate

p = Table()
p.show_table() # 1ste test to make sure the table class works, has a capacity and can show the seats

p.assign_seat("Pierrick")
print(p.has_free_spot())
print(p.left_capacity())
p.show_table()
p.assign_seat("Michiel")
p.show_table()
# Out:
# Table has a capacity of: 4
# empthy seat
# empthy seat
# empthy seat
# empthy seat
# True
# 3
# Table has a capacity of: 4
# Pierrick
# empthy seat
# empthy seat
# empthy seat
# Table has a capacity of: 4
# Pierrick
# empthy seat
# empthy seat
# empthy seat

# %% [markdown]
# Does the output of you test make sense? Check that each method returns the correct value.

# %% [markdown]
# ## Step 3: Build an OpenSpace
#
# Create a class `Openspace` that contains these attributes:
#
# - `tables` which is a list of `Table`. _(you will need to import `Table` from `table.py`)_.
# - `number_of_tables` which is an integer.
#
# And some methods:
#
# - `organize(names)` that will:
#   - **randomly** assign people to `Seat` objects in the different `Table` objects.
# - `display()` display the different tables and there occupants in a nice and readable way
# - `store(filename)` store the repartition in an file

# %%
# Your code here
import random
import csv
from pathlib import Path

class Openspace:
    def __init__(self, tables): #number_of_tables = 6
        self.tables = tables

    def total_capacity(self):
        total = 0 

        for table in self.tables:
            total += table.capacity

        return total

    def orginize(self, names):
        if len(names) > self.total_capacity():
             raise Exception("Not enough seats for everyone")
        
        random.shuffle(names)

        index = 0
        for table in self.tables:
             while table.has_free_spot() and index < len(names):
                  table.assign_seat(names[index])
                  index += 1
    
    def display(self):
        print("Open space display:")
        for i, table in enumerate(self.tables, start=1):
            print(f"\nTafel {i}:")
            table.show_table()

    def store(self, filename="openspace.csv"):
        """saves repartition in a CSVfile"""
        path = Path(filename)
        with path.open("w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["Table", "Seat", "Name"])

            for table_index, table in enumerate(self.tables, start=1):
                for seat_index, seat in enumerate(table.seats, start=1):
                    naam = seat.occupant if not seat.free else ""
                    writer.writerow([table_index, seat_index, naam])
                    
        print(f"Stored repartition in file: {filename}")

# %%
# Test your code (assign everyone in the class to a table)
o = Openspace()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Test your code (assign everyone in the class to a table)
# ----> 2 o = Openspace()
#
# NameError: name 'Openspace' is not defined

# %% [markdown]
# Hurray! You have the algorithm logic working. Next steps we transform this into some scripts! **Big note:** Once you move to the scrips you may need to adapt your logic, don't fret this is normal!
